# %%
import pandas as pd

# %%
#Reading in the dataframe
cities_df = pd.read_csv('Resources/cities_weather.csv')

cities_df
# Out:
#                City Country  Latitude  Longitude  Temperature (F)  \
# 0       henties bay     NaN  -22.1160    14.2845            66.85
# 1            bethel      US   41.3712   -73.4140            31.98
# 2    saint-francois      FR   46.4154     3.9054            26.04
# 3           ushuaia      AR  -54.8000   -68.3000            42.46
# 4     mar del plata      AR  -38.0023   -57.5575            71.91
# ..              ...     ...       ...        ...              ...
# 539       vredendal      ZA  -31.6683    18.5012            65.86
# 540         kushima      JP   31.4583   131.2333            44.64
# 541        eirunepe      BR   -6.6603   -69.8736            74.89
# 542       tocopilla      CL  -22.0920   -70.1979            69.76
# 543     verkhoyansk      RU   67.5447   133.3850           -15.39
#
#      Max Temp (F)  Humidity %  Cloudiness  Wind Speed (mph)        Date
# 0           66.85          84           8              5.50  1643152035
# ...

# %%
#Dropping the extra temperature column
cities_df.drop(['Temperature (F)'], axis='columns', inplace=True)

cities_df
# Out:
#                City Country  Latitude  Longitude  Max Temp (F)  Humidity %  \
# 0       henties bay     NaN  -22.1160    14.2845         66.85          84
# 1            bethel      US   41.3712   -73.4140         36.05          60
# 2    saint-francois      FR   46.4154     3.9054         26.67          93
# 3           ushuaia      AR  -54.8000   -68.3000         42.46          81
# 4     mar del plata      AR  -38.0023   -57.5575         73.09          97
# ..              ...     ...       ...        ...           ...         ...
# 539       vredendal      ZA  -31.6683    18.5012         65.86          77
# 540         kushima      JP   31.4583   131.2333         45.91          77
# 541        eirunepe      BR   -6.6603   -69.8736         74.89          96
# 542       tocopilla      CL  -22.0920   -70.1979         69.76          65
# 543     verkhoyansk      RU   67.5447   133.3850        -15.39         100
#
#      Cloudiness  Wind Speed (mph)        Date
# ...

# %%
#Writing the file to HTML code
print(cities_df.to_html())
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>City</th>
#       <th>Country</th>
#       <th>Latitude</th>
#       <th>Longitude</th>
#       <th>Max Temp (F)</th>
#       <th>Humidity %</th>
#       <th>Cloudiness</th>
#       <th>Wind Speed (mph)</th>
#       <th>Date</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>henties bay</td>
#       <td>NaN</td>
#       <td>-22.1160</td>
#       <td>14.2845</td>
#       <td>66.85</td>
#       <td>84</td>
#       <td>8</td>
#       <td>5.50</td>
#       <td>1643152035</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>bethel</td>
#       <td>US</td>
#       <td>41.3712</td>
#       <td>-73.4140</td>
#       <td>36.05</td>
#       <td>60</td>
#       <td>0</td>
#       <td>8.05</td>
#       <td>1643152010</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>saint-francois</td>
#       <td>FR</td>
#       <td>46.4154</td>
# ...
